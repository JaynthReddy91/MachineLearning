# %% [markdown]
# <a href="https://colab.research.google.com/github/JaynthReddy91/MachineLearning/blob/main/titanic_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("titanic_train.csv")

# 1. Constant Features
constant_features = [col for col in df.columns if df[col].nunique() == 1]
print("Constant Features:", constant_features)

# 2. Quasi-constant Features (threshold = 99%)
quasi_constant_features = []
for col in df.columns:
    top_freq = df[col].value_counts(normalize=True, dropna=False).values[0]
    if top_freq > 0.99:
        quasi_constant_features.append(col)
print("Quasi-constant Features:", quasi_constant_features)

# 3. Duplicate Features
duplicate_features = []
for i in range(len(df.columns)):
    for j in range(i+1, len(df.columns)):
        if df.iloc[:, i].equals(df.iloc[:, j]):
            duplicate_features.append(df.columns[j])
print("Duplicate Features:", duplicate_features)
# Out:
# Constant Features: []
# Quasi-constant Features: []
# Duplicate Features: []

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import chi2, f_classif, f_regression, SelectKBest
from sklearn.metrics import roc_auc_score, mean_squared_error
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_csv("titanic_train.csv")

# Example target (Survived = classification, Age = regression)
y_class = df["Survived"]
y_reg = df["Age"].fillna(df["Age"].median())  # fill NA for regression
X = df.drop(columns=["Survived", "Age"])

# Convert categorical to numeric for statistical tests
X = pd.get_dummies(X, drop_first=True)

# ------------------------
# 1. Correlation
# ------------------------
corr_matrix = X.corr()
print("Correlation Matrix:\n", corr_matrix)

# ------------------------
# 2. Mutual Information
# ------------------------
mi_class = mutual_info_classif(X.fillna(0), y_class)
mi_reg = mutual_info_regression(X.fillna(0), y_reg)

print("Mutual Information (Classification):", dict(zip(X.columns, mi_class)))
print("Mutual Information (Regression):", dict(zip(X.columns, mi_reg)))

# ------------------------
# 3. Chi-Square (Classification, categorical data only)
# ------------------------
X_chi2 = X.fillna(0)
chi_scores, p_values = chi2(X_chi2, y_class)
print("Chi-Square Scores:", dict(zip(X.columns, chi_scores)))
print("Chi-Square p-values:", dict(zip(X.columns, p_values)))

# ------------------------
# 4. ANOVA / Univariate Feature Selection
# ------------------------
anova_class = SelectKBest(score_func=f_classif, k=5).fit(X.fillna(0), y_class)
anova_reg = SelectKBest(score_func=f_regression, k=5).fit(X.fillna(0), y_reg)

print("ANOVA (Classification) Scores:", dict(zip(X.columns, anova_class.scores_)))
print("ANOVA (Regression) Scores:", dict(zip(X.columns, anova_reg.scores_)))

# ------------------------
# 5. Univariate ROC-AUC (Classification) & MSE (Regression)
# ------------------------
X_train, X_test, y_train, y_test = train_test_split(X.fillna(0), y_class, test_size=0.3, random_state=42)

roc_auc_scores = {}
for col in X.columns:
    try:
        score = roc_auc_score(y_test, X_test[col])
        roc_auc_scores[col] = score
    except:
        pass
print("Univariate ROC-AUC (Classification):", roc_auc_scores)

# Regression MSE
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X.fillna(0), y_reg, test_size=0.3, random_state=42)
mse_scores = {}
for col in X.columns:
    preds = X_test_r[col]
    score = mean_squared_error(y_test_r, preds)
    mse_scores[col] = score
print("Univariate MSE (Regression):", mse_scores)
# Out:
# Correlation Matrix:
#               PassengerId    Pclass     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.035144 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000  0.083081  0.018443 -0.549500
# SibSp          -0.057527  0.083081  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.159651  0.216225  1.000000
# ...                  ...       ...       ...       ...       ...
# Cabin_F4       -0.008206 -0.017519  0.063564  0.036410  0.006490
# Cabin_G6       -0.060049  0.055561 -0.001402  0.072388 -0.025180
# Cabin_T        -0.013814 -0.052496 -0.015907 -0.015878  0.002224
# Embarked_Q     -0.033606  0.221009 -0.026354 -0.081228 -0.117216
# Embarked_S      0.022148  0.081720  0.070941  0.063036 -0.166603
#
#              Name_Abbott, Mr. Rossmore Edward  \
# PassengerId                          0.039227
# Pclass                               0.027734
# SibSp                                0.014507
# Parch                                0.025731
# Fare                                -0.008068
# ...                                       ...
# Cabin_F4                            -0.001590
# Cabin_G6                            -0.002251
# Cabin_T                             -0.001124
# Embarked_Q                          -0.010310
# Embarked_S                           0.020759
#
#              Name_Abbott, Mrs. Stanton (Rosa Hunt)  Name_Abelson, Mr. Samuel  \
# PassengerId                              -0.021633                 -0.017854
# Pclass                                    0.027734                 -0.012381
# SibSp                                     0.014507                  0.014507
# Parch                                     0.025731                 -0.015878
# Fare                                     -0.008068                 -0.005537
# ...                                            ...                       ...
# Cabin_F4                                 -0.001590                 -0.001590
# Cabin_G6                                 -0.002251                 -0.002251
# Cabin_T                                  -0.001124                 -0.001124
# Embarked_Q                               -0.010310                 -0.010310
# Embarked_S                                0.020759                 -0.054125
#
#              Name_Abelson, Mrs. Samuel (Hannah Wizosky)  \
# PassengerId                                    0.055908
# Pclass                                        -0.012381
# SibSp                                          0.014507
# Parch                                         -0.015878
# Fare                                          -0.005537
# ...                                                 ...
# Cabin_F4                                      -0.001590
# Cabin_G6                                      -0.002251
# Cabin_T                                       -0.001124
# Embarked_Q                                    -0.010310
# Embarked_S                                    -0.054125
#
#              Name_Adahl, Mr. Mauritz Nils Martin  ...  Cabin_F G63  \
# PassengerId                            -0.010426  ...     0.033102
# Pclass                                  0.027734  ...     0.027734
# SibSp                                  -0.015907  ...    -0.015907
# Parch                                  -0.015878  ...    -0.015878
# Fare                                   -0.016842  ...    -0.016572
# ...                                          ...  ...          ...
# Cabin_F4                               -0.001590  ...    -0.001590
# Cabin_G6                               -0.002251  ...    -0.002251
# Cabin_T                                -0.001124  ...    -0.001124
# Embarked_Q                             -0.010310  ...    -0.010310
# Embarked_S                              0.020759  ...     0.020759
#
#              Cabin_F G73  Cabin_F2  Cabin_F33  Cabin_F38  Cabin_F4  Cabin_G6  \
# PassengerId    -0.009220 -0.049263  -0.030733   0.043137 -0.008206 -0.060049
# Pclass          0.039243 -0.021469  -0.021469   0.027734 -0.017519  0.055561
# SibSp          -0.022508  0.007576  -0.027582  -0.015907  0.063564 -0.001402
# Parch          -0.022467  0.068667  -0.027532  -0.015878  0.036410  0.072388
# Fare           -0.023450 -0.007261  -0.024425  -0.016505  0.006490 -0.025180
# ...                  ...       ...        ...        ...       ...       ...
# Cabin_F4       -0.002250 -0.002757  -0.002757  -0.001590  1.000000 -0.003185
# Cabin_G6       -0.003185 -0.003903  -0.003903  -0.002251 -0.003185  1.000000
# Cabin_T        -0.001590 -0.001948  -0.001948  -0.001124 -0.001590 -0.002251
# Embarked_Q     -0.014588 -0.017877  -0.017877   0.108986 -0.014588 -0.020654
# Embarked_S      0.029374  0.035996   0.035996  -0.054125  0.029374  0.041589
#
#               Cabin_T  Embarked_Q  Embarked_S
# PassengerId -0.013814   -0.033606    0.022148
# Pclass      -0.052496    0.221009    0.081720
# SibSp       -0.015907   -0.026354    0.070941
# Parch       -0.015878   -0.081228    0.063036
# Fare         0.002224   -0.117216   -0.166603
# ...               ...         ...         ...
# Cabin_F4    -0.001590   -0.014588    0.029374
# Cabin_G6    -0.002251   -0.020654    0.041589
# Cabin_T      1.000000   -0.010310    0.020759
# Embarked_Q  -0.010310    1.000000   -0.496624
# Embarked_S   0.020759   -0.496624    1.000000
#
# [1724 rows x 1724 columns]
# Mutual Information (Classification): {'PassengerId': np.float64(0.014689088943916184), 'Pclass': np.float64(0.06030837995914751), 'SibSp': np.float64(0.018032934196651862), 'Parch': np.float64(0.011524734062503539), 'Fare': np.float64(0.11801901791044522), 'Name_Abbott, Mr. Rossmore Edward': np.float64(0.0), 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': np.float64(0.0), 'Name_Abelson, Mr. Samuel': np.float64(0.00310794614489307), 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': np.float64(0.0), 'Name_Adahl, Mr. Mauritz Nils Martin': np.float64(0.0), 'Name_Adams, Mr. John': np.float64(0.009454041469655117), 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': np.float64(0.007728741616013224), 'Name_Aks, Mrs. Sam (Leah Rosen)': np.float64(0.017835758910097255), 'Name_Albimona, Mr. Nassef Cassem': np.float64(0.0015027599593664398), 'Name_Alexander, Mr. William': np.float64(0.003256033382659229), 'Name_Alhomaki, Mr. Ilmari Rudolf': np.float64(0.0), 'Name_Ali, Mr. Ahmed': np.float64(0.001983534899144601), 'Name_Ali, Mr. William': np.float64(0.013202800194125563), 'Name_Allen, Miss. Elisabeth Walton': np.float64(0.005619960977481853), 'Name_Allen, Mr. William Henry': np.float64(0.007786209493320317), 'Name_Allison, Master. Hudson Trevor': np.float64(0.013334184716617958), 'Name_Allison, Miss. Helen Loraine': np.float64(0.0), 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': np.float64(0.024525114999673026), 'Name_Allum, Mr. Owen George': np.float64(0.0), 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': np.float64(0.0), 'Name_Anderson, Mr. Harry': np.float64(0.0), 'Name_Andersson, Master. Sigvard Harald Elias': np.float64(0.0), 'Name_Andersson, Miss. Ebba Iris Alfrida': np.float64(0.0), 'Name_Andersson, Miss. Ellis Anna Maria': np.float64(0.0), 'Name_Andersson, Miss. Erna Alexandra': np.float64(0.01212401921768369), 'Name_Andersson, Miss. Ingeborg Constanzia': np.float64(0.0), 'Name_Andersson, Miss. Sigrid Elisabeth': np.float64(0.03490022520633307), 'Name_Andersson, Mr. Anders Johan': np.float64(0.0), 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': np.float64(0.0), 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': np.float64(0.0), 'Name_Andreasson, Mr. Paul Edvin': np.float64(0.0), 'Name_Andrew, Mr. Edgardo Samuel': np.float64(0.01720220266287087), 'Name_Andrews, Miss. Kornelia Theodosia': np.float64(0.011926235644479366), 'Name_Andrews, Mr. Thomas Jr': np.float64(0.03619102111002381), 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': np.float64(0.0), 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': np.float64(0.0016431003522323628), 'Name_Arnold-Franchi, Mr. Josef': np.float64(0.0), 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': np.float64(0.010914868597758698), 'Name_Artagaveytia, Mr. Ramon': np.float64(0.0), 'Name_Asim, Mr. Adola': np.float64(0.0), 'Name_Asplund, Master. Clarence Gustaf Hugo': np.float64(0.0), 'Name_Asplund, Master. Edvin Rojj Felix': np.float64(0.0038971690140481297), 'Name_Asplund, Miss. Lillian Gertrud': np.float64(0.009477442376495837), 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': np.float64(0.0), 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': np.float64(0.021647879214409915), 'Name_Attalah, Miss. Malake': np.float64(0.0), 'Name_Attalah, Mr. Sleiman': np.float64(0.0), 'Name_Aubart, Mme. Leontine Pauline': np.float64(0.006776087602695879), 'Name_Augustsson, Mr. Albert': np.float64(0.018117014379326113), 'Name_Ayoub, Miss. Banoura': np.float64(0.0), 'Name_Backstrom, Mr. Karl Alfred': np.float64(0.005860020634596452), 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)': np.float64(0.017265721639722953), 'Name_Baclini, Miss. Eugenie': np.float64(0.0030868927097966736), 'Name_Baclini, Miss. Helene Barbara': np.float64(0.007493355194592155), 'Name_Baclini, Miss. Marie Catherine': np.float64(0.010001050516523557), 'Name_Baclini, Mrs. Solomon (Latifa Qurban)': np.float64(0.007546264901802324), 'Name_Badt, Mr. Mohamed': np.fl ...
# Mutual Information (Regression): {'PassengerId': np.float64(0.0), 'Pclass': np.float64(0.09755346780278806), 'SibSp': np.float64(0.11380225449400339), 'Parch': np.float64(0.14531016165895672), 'Fare': np.float64(0.14691886618826988), 'Name_Abbott, Mr. Rossmore Edward': np.float64(0.0), 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': np.float64(0.018479271794853425), 'Name_Abelson, Mr. Samuel': np.float64(0.0), 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': np.float64(0.026074804762628245), 'Name_Adahl, Mr. Mauritz Nils Martin': np.float64(0.005409973787139588), 'Name_Adams, Mr. John': np.float64(0.008469798997140066), 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': np.float64(0.007583516503299359), 'Name_Aks, Mrs. Sam (Leah Rosen)': np.float64(0.0027155695389109447), 'Name_Albimona, Mr. Nassef Cassem': np.float64(0.0), 'Name_Alexander, Mr. William': np.float64(0.010023622457585812), 'Name_Alhomaki, Mr. Ilmari Rudolf': np.float64(0.0027871263383887346), 'Name_Ali, Mr. Ahmed': np.float64(0.01040529588246697), 'Name_Ali, Mr. William': np.float64(0.0), 'Name_Allen, Miss. Elisabeth Walton': np.float64(0.017812615004760834), 'Name_Allen, Mr. William Henry': np.float64(0.017215429744772637), 'Name_Allison, Master. Hudson Trevor': np.float64(0.004424457915728874), 'Name_Allison, Miss. Helen Loraine': np.float64(0.0), 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': np.float64(0.006020658073374596), 'Name_Allum, Mr. Owen George': np.float64(0.0), 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': np.float64(0.026403270049743632), 'Name_Anderson, Mr. Harry': np.float64(0.0), 'Name_Andersson, Master. Sigvard Harald Elias': np.float64(0.01287606339696512), 'Name_Andersson, Miss. Ebba Iris Alfrida': np.float64(0.0), 'Name_Andersson, Miss. Ellis Anna Maria': np.float64(0.016055537002677367), 'Name_Andersson, Miss. Erna Alexandra': np.float64(0.00878795910816188), 'Name_Andersson, Miss. Ingeborg Constanzia': np.float64(0.0), 'Name_Andersson, Miss. Sigrid Elisabeth': np.float64(0.0), 'Name_Andersson, Mr. Anders Johan': np.float64(0.016580244352398577), 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': np.float64(0.0008856586173224823), 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': np.float64(0.0031343904566512037), 'Name_Andreasson, Mr. Paul Edvin': np.float64(0.008336301908759225), 'Name_Andrew, Mr. Edgardo Samuel': np.float64(0.009990157275751477), 'Name_Andrews, Miss. Kornelia Theodosia': np.float64(0.02461588713065077), 'Name_Andrews, Mr. Thomas Jr': np.float64(0.010409494383533557), 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': np.float64(0.017951713202986053), 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': np.float64(0.018999128085675165), 'Name_Arnold-Franchi, Mr. Josef': np.float64(0.01526152201288844), 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': np.float64(0.0031106598005288255), 'Name_Artagaveytia, Mr. Ramon': np.float64(0.0), 'Name_Asim, Mr. Adola': np.float64(0.0038635184341677675), 'Name_Asplund, Master. Clarence Gustaf Hugo': np.float64(0.0), 'Name_Asplund, Master. Edvin Rojj Felix': np.float64(0.0003832018621479083), 'Name_Asplund, Miss. Lillian Gertrud': np.float64(0.0), 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': np.float64(0.022401391436400298), 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': np.float64(0.0), 'Name_Attalah, Miss. Malake': np.float64(0.0), 'Name_Attalah, Mr. Sleiman': np.float64(0.0), 'Name_Aubart, Mme. Leontine Pauline': np.float64(0.0), 'Name_Augustsson, Mr. Albert': np.float64(0.0), 'Name_Ayoub, Miss. Banoura': np.float64(0.025570966689932195), 'Name_Backstrom, Mr. Karl Alfred': np.float64(0.0), 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)': np.float64(0.015280895233134473), 'Name_Baclini, Miss. Eugenie': np.float64(0.0), 'Name_Baclini, Miss. Helene Barbara': np.float64(0.0010793463348102161), 'Name_Baclini, Miss. Marie Catherine': np.float64(0.001831723980610267), 'Name_Baclini, Mrs. Solomon  ...
# Chi-Square Scores: {'PassengerId': np.float64(3.3129340664017617), 'Pclass': np.float64(30.873699436634034), 'SibSp': np.float64(2.5818653789895856), 'Parch': np.float64(10.097499111810386), 'Fare': np.float64(4518.319090638635), 'Name_Abbott, Mr. Rossmore Edward': np.float64(0.6229508196721312), 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': np.float64(1.6052631578947367), 'Name_Abelson, Mr. Samuel': np.float64(0.6229508196721312), 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': np.float64(1.6052631578947367), 'Name_Adahl, Mr. Mauritz Nils Martin': np.float64(0.6229508196721312), 'Name_Adams, Mr. John': np.float64(0.6229508196721312), 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': np.float64(0.6229508196721312), 'Name_Aks, Mrs. Sam (Leah Rosen)': np.float64(1.6052631578947367), 'Name_Albimona, Mr. Nassef Cassem': np.float64(1.6052631578947367), 'Name_Alexander, Mr. William': np.float64(0.6229508196721312), 'Name_Alhomaki, Mr. Ilmari Rudolf': np.float64(0.6229508196721312), 'Name_Ali, Mr. Ahmed': np.float64(0.6229508196721312), 'Name_Ali, Mr. William': np.float64(0.6229508196721312), 'Name_Allen, Miss. Elisabeth Walton': np.float64(1.6052631578947367), 'Name_Allen, Mr. William Henry': np.float64(0.6229508196721312), 'Name_Allison, Master. Hudson Trevor': np.float64(1.6052631578947367), 'Name_Allison, Miss. Helen Loraine': np.float64(0.6229508196721312), 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': np.float64(0.6229508196721312), 'Name_Allum, Mr. Owen George': np.float64(0.6229508196721312), 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': np.float64(1.6052631578947367), 'Name_Anderson, Mr. Harry': np.float64(1.6052631578947367), 'Name_Andersson, Master. Sigvard Harald Elias': np.float64(0.6229508196721312), 'Name_Andersson, Miss. Ebba Iris Alfrida': np.float64(0.6229508196721312), 'Name_Andersson, Miss. Ellis Anna Maria': np.float64(0.6229508196721312), 'Name_Andersson, Miss. Erna Alexandra': np.float64(1.6052631578947367), 'Name_Andersson, Miss. Ingeborg Constanzia': np.float64(0.6229508196721312), 'Name_Andersson, Miss. Sigrid Elisabeth': np.float64(0.6229508196721312), 'Name_Andersson, Mr. Anders Johan': np.float64(0.6229508196721312), 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': np.float64(1.6052631578947367), 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': np.float64(0.6229508196721312), 'Name_Andreasson, Mr. Paul Edvin': np.float64(0.6229508196721312), 'Name_Andrew, Mr. Edgardo Samuel': np.float64(0.6229508196721312), 'Name_Andrews, Miss. Kornelia Theodosia': np.float64(1.6052631578947367), 'Name_Andrews, Mr. Thomas Jr': np.float64(0.6229508196721312), 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': np.float64(1.6052631578947367), 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': np.float64(1.6052631578947367), 'Name_Arnold-Franchi, Mr. Josef': np.float64(0.6229508196721312), 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': np.float64(0.6229508196721312), 'Name_Artagaveytia, Mr. Ramon': np.float64(0.6229508196721312), 'Name_Asim, Mr. Adola': np.float64(0.6229508196721312), 'Name_Asplund, Master. Clarence Gustaf Hugo': np.float64(0.6229508196721312), 'Name_Asplund, Master. Edvin Rojj Felix': np.float64(1.6052631578947367), 'Name_Asplund, Miss. Lillian Gertrud': np.float64(1.6052631578947367), 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': np.float64(1.6052631578947367), 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': np.float64(1.6052631578947367), 'Name_Attalah, Miss. Malake': np.float64(0.6229508196721312), 'Name_Attalah, Mr. Sleiman': np.float64(0.6229508196721312), 'Name_Aubart, Mme. Leontine Pauline': np.float64(1.6052631578947367), 'Name_Augustsson, Mr. Albert': np.float64(0.6229508196721312), 'Name_Ayoub, Miss. Banoura': np.float64(1.6052631578947367), 'Name_Backstrom, Mr. Karl Alfred': np.float64(0.6229508196721312), 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)': np.float64(1.6052631578947367), 'Name_Bac ...
# Chi-Square p-values: {'PassengerId': np.float64(0.06873666505857781), 'Pclass': np.float64(2.7537856320284722e-08), 'SibSp': np.float64(0.10809421012689488), 'Parch': np.float64(0.0014847067586887819), 'Fare': np.float64(0.0), 'Name_Abbott, Mr. Rossmore Edward': np.float64(0.42995285199523137), 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': np.float64(0.20515893643829386), 'Name_Abelson, Mr. Samuel': np.float64(0.42995285199523137), 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': np.float64(0.20515893643829386), 'Name_Adahl, Mr. Mauritz Nils Martin': np.float64(0.42995285199523137), 'Name_Adams, Mr. John': np.float64(0.42995285199523137), 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': np.float64(0.42995285199523137), 'Name_Aks, Mrs. Sam (Leah Rosen)': np.float64(0.20515893643829386), 'Name_Albimona, Mr. Nassef Cassem': np.float64(0.20515893643829386), 'Name_Alexander, Mr. William': np.float64(0.42995285199523137), 'Name_Alhomaki, Mr. Ilmari Rudolf': np.float64(0.42995285199523137), 'Name_Ali, Mr. Ahmed': np.float64(0.42995285199523137), 'Name_Ali, Mr. William': np.float64(0.42995285199523137), 'Name_Allen, Miss. Elisabeth Walton': np.float64(0.20515893643829386), 'Name_Allen, Mr. William Henry': np.float64(0.42995285199523137), 'Name_Allison, Master. Hudson Trevor': np.float64(0.20515893643829386), 'Name_Allison, Miss. Helen Loraine': np.float64(0.42995285199523137), 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': np.float64(0.42995285199523137), 'Name_Allum, Mr. Owen George': np.float64(0.42995285199523137), 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': np.float64(0.20515893643829386), 'Name_Anderson, Mr. Harry': np.float64(0.20515893643829386), 'Name_Andersson, Master. Sigvard Harald Elias': np.float64(0.42995285199523137), 'Name_Andersson, Miss. Ebba Iris Alfrida': np.float64(0.42995285199523137), 'Name_Andersson, Miss. Ellis Anna Maria': np.float64(0.42995285199523137), 'Name_Andersson, Miss. Erna Alexandra': np.float64(0.20515893643829386), 'Name_Andersson, Miss. Ingeborg Constanzia': np.float64(0.42995285199523137), 'Name_Andersson, Miss. Sigrid Elisabeth': np.float64(0.42995285199523137), 'Name_Andersson, Mr. Anders Johan': np.float64(0.42995285199523137), 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': np.float64(0.20515893643829386), 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': np.float64(0.42995285199523137), 'Name_Andreasson, Mr. Paul Edvin': np.float64(0.42995285199523137), 'Name_Andrew, Mr. Edgardo Samuel': np.float64(0.42995285199523137), 'Name_Andrews, Miss. Kornelia Theodosia': np.float64(0.20515893643829386), 'Name_Andrews, Mr. Thomas Jr': np.float64(0.42995285199523137), 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': np.float64(0.20515893643829386), 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': np.float64(0.20515893643829386), 'Name_Arnold-Franchi, Mr. Josef': np.float64(0.42995285199523137), 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': np.float64(0.42995285199523137), 'Name_Artagaveytia, Mr. Ramon': np.float64(0.42995285199523137), 'Name_Asim, Mr. Adola': np.float64(0.42995285199523137), 'Name_Asplund, Master. Clarence Gustaf Hugo': np.float64(0.42995285199523137), 'Name_Asplund, Master. Edvin Rojj Felix': np.float64(0.20515893643829386), 'Name_Asplund, Miss. Lillian Gertrud': np.float64(0.20515893643829386), 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': np.float64(0.20515893643829386), 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': np.float64(0.20515893643829386), 'Name_Attalah, Miss. Malake': np.float64(0.42995285199523137), 'Name_Attalah, Mr. Sleiman': np.float64(0.42995285199523137), 'Name_Aubart, Mme. Leontine Pauline': np.float64(0.20515893643829386), 'Name_Augustsson, Mr. Albert': np.float64(0.42995285199523137), 'Name_Ayoub, Miss. Banoura': np.float64(0.20515893643829386), 'Name_Backstrom, Mr. Karl Alfred': np.float64(0.42995285199523137), 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafs ...
# ANOVA (Classification) Scores: {'PassengerId': np.float64(0.02228481226615959), 'Pclass': np.float64(115.03127218827744), 'SibSp': np.float64(1.1105722041132329), 'Parch': np.float64(5.963463836603494), 'Fare': np.float64(63.03076422804438), 'Name_Abbott, Mr. Rossmore Edward': np.float64(0.6226867212268672), 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': np.float64(1.6063568233656207), 'Name_Abelson, Mr. Samuel': np.float64(0.6226867212268672), 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': np.float64(1.6063568233656207), 'Name_Adahl, Mr. Mauritz Nils Martin': np.float64(0.6226867212268672), 'Name_Adams, Mr. John': np.float64(0.6226867212268672), 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': np.float64(0.6226867212268672), 'Name_Aks, Mrs. Sam (Leah Rosen)': np.float64(1.6063568233656207), 'Name_Albimona, Mr. Nassef Cassem': np.float64(1.6063568233656207), 'Name_Alexander, Mr. William': np.float64(0.6226867212268672), 'Name_Alhomaki, Mr. Ilmari Rudolf': np.float64(0.6226867212268672), 'Name_Ali, Mr. Ahmed': np.float64(0.6226867212268672), 'Name_Ali, Mr. William': np.float64(0.6226867212268672), 'Name_Allen, Miss. Elisabeth Walton': np.float64(1.6063568233656207), 'Name_Allen, Mr. William Henry': np.float64(0.6226867212268672), 'Name_Allison, Master. Hudson Trevor': np.float64(1.6063568233656207), 'Name_Allison, Miss. Helen Loraine': np.float64(0.6226867212268672), 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': np.float64(0.6226867212268672), 'Name_Allum, Mr. Owen George': np.float64(0.6226867212268672), 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': np.float64(1.6063568233656207), 'Name_Anderson, Mr. Harry': np.float64(1.6063568233656207), 'Name_Andersson, Master. Sigvard Harald Elias': np.float64(0.6226867212268672), 'Name_Andersson, Miss. Ebba Iris Alfrida': np.float64(0.6226867212268672), 'Name_Andersson, Miss. Ellis Anna Maria': np.float64(0.6226867212268672), 'Name_Andersson, Miss. Erna Alexandra': np.float64(1.6063568233656207), 'Name_Andersson, Miss. Ingeborg Constanzia': np.float64(0.6226867212268672), 'Name_Andersson, Miss. Sigrid Elisabeth': np.float64(0.6226867212268672), 'Name_Andersson, Mr. Anders Johan': np.float64(0.6226867212268672), 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': np.float64(1.6063568233656207), 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': np.float64(0.6226867212268672), 'Name_Andreasson, Mr. Paul Edvin': np.float64(0.6226867212268672), 'Name_Andrew, Mr. Edgardo Samuel': np.float64(0.6226867212268672), 'Name_Andrews, Miss. Kornelia Theodosia': np.float64(1.6063568233656207), 'Name_Andrews, Mr. Thomas Jr': np.float64(0.6226867212268672), 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': np.float64(1.6063568233656207), 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': np.float64(1.6063568233656207), 'Name_Arnold-Franchi, Mr. Josef': np.float64(0.6226867212268672), 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': np.float64(0.6226867212268672), 'Name_Artagaveytia, Mr. Ramon': np.float64(0.6226867212268672), 'Name_Asim, Mr. Adola': np.float64(0.6226867212268672), 'Name_Asplund, Master. Clarence Gustaf Hugo': np.float64(0.6226867212268672), 'Name_Asplund, Master. Edvin Rojj Felix': np.float64(1.6063568233656207), 'Name_Asplund, Miss. Lillian Gertrud': np.float64(1.6063568233656207), 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': np.float64(1.6063568233656207), 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': np.float64(1.6063568233656207), 'Name_Attalah, Miss. Malake': np.float64(0.6226867212268672), 'Name_Attalah, Mr. Sleiman': np.float64(0.6226867212268672), 'Name_Aubart, Mme. Leontine Pauline': np.float64(1.6063568233656207), 'Name_Augustsson, Mr. Albert': np.float64(0.6226867212268672), 'Name_Ayoub, Miss. Banoura': np.float64(1.6063568233656207), 'Name_Backstrom, Mr. Karl Alfred': np.float64(0.6226867212268672), 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)': np.float64(1.6063568233656207 ...
# ANOVA (Regression) Scores: {'PassengerId': np.float64(1.0417659462446773), 'Pclass': np.float64(116.12270412732362), 'SibSp': np.float64(51.170846159693), 'Parch': np.float64(27.258719319132798), 'Fare': np.float64(8.389380111163733), 'Name_Abbott, Mr. Rossmore Edward': np.float64(1.054455701363073), 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': np.float64(0.18758746723667064), 'Name_Abelson, Mr. Samuel': np.float64(0.0024044097454707244), 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': np.float64(0.010936818034943589), 'Name_Adahl, Mr. Mauritz Nils Martin': np.float64(0.0024044097454707244), 'Name_Adams, Mr. John': np.float64(0.06666806356327912), 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': np.float64(0.6681563083724993), 'Name_Aks, Mrs. Sam (Leah Rosen)': np.float64(0.7621624556915094), 'Name_Albimona, Mr. Nassef Cassem': np.float64(0.06666806356327912), 'Name_Alexander, Mr. William': np.float64(0.06666806356327912), 'Name_Alhomaki, Mr. Ilmari Rudolf': np.float64(0.5173076560989373), 'Name_Ali, Mr. Ahmed': np.float64(0.1696159013699951), 'Name_Ali, Mr. William': np.float64(0.11223821105223426), 'Name_Allen, Miss. Elisabeth Walton': np.float64(0.0007712814566363283), 'Name_Allen, Mr. William Henry': np.float64(0.18758746723667064), 'Name_Allison, Master. Hudson Trevor': np.float64(4.797806900000274), 'Name_Allison, Miss. Helen Loraine': np.float64(4.438570137251879), 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': np.float64(0.11223821105223426), 'Name_Allum, Mr. Owen George': np.float64(0.7621624556915094), 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': np.float64(0.633810491561884), 'Name_Anderson, Mr. Harry': np.float64(2.0540835415178225), 'Name_Andersson, Master. Sigvard Harald Elias': np.float64(3.810728994487729), 'Name_Andersson, Miss. Ebba Iris Alfrida': np.float64(3.2313049010066166), 'Name_Andersson, Miss. Ellis Anna Maria': np.float64(4.438570137251879), 'Name_Andersson, Miss. Erna Alexandra': np.float64(0.9023737934234642), 'Name_Andersson, Miss. Ingeborg Constanzia': np.float64(2.452546511445995), 'Name_Andersson, Miss. Sigrid Elisabeth': np.float64(1.9933825904375309), 'Name_Andersson, Mr. Anders Johan': np.float64(0.5483741900455947), 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': np.float64(0.032901828992416865), 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': np.float64(0.5483741900455947), 'Name_Andreasson, Mr. Paul Edvin': np.float64(0.5173076560989373), 'Name_Andrew, Mr. Edgardo Samuel': np.float64(0.7621624556915094), 'Name_Andrews, Miss. Kornelia Theodosia': np.float64(6.725772132033689), 'Name_Andrews, Mr. Thomas Jr': np.float64(0.5483741900455947), 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': np.float64(0.26004821268453465), 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': np.float64(3.3086273561244006), 'Name_Arnold-Franchi, Mr. Josef': np.float64(0.11223821105223426), 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': np.float64(0.7621624556915094), 'Name_Artagaveytia, Mr. Ramon': np.float64(10.346933441669314), 'Name_Asim, Mr. Adola': np.float64(0.18758746723667064), 'Name_Asplund, Master. Clarence Gustaf Hugo': np.float64(2.452546511445995), 'Name_Asplund, Master. Edvin Rojj Felix': np.float64(4.118585137828824), 'Name_Asplund, Miss. Lillian Gertrud': np.float64(3.5149768632380063), 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': np.float64(0.4404343833950021), 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': np.float64(0.7621624556915094), 'Name_Attalah, Miss. Malake': np.float64(0.9023737934234642), 'Name_Attalah, Mr. Sleiman': np.float64(0.0024044097454707244), 'Name_Aubart, Mme. Leontine Pauline': np.float64(0.1696159013699951), 'Name_Augustsson, Mr. Albert': np.float64(0.23880570575625684), 'Name_Ayoub, Miss. Banoura': np.float64(1.5820511358743943), 'Name_Backstrom, Mr. Karl Alfred': np.float64(0.0410681207075228), 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)': np.float64(0.078101 ...
# Univariate ROC-AUC (Classification): {'PassengerId': np.float64(0.4789694152751477), 'Pclass': np.float64(0.29270671945831184), 'SibSp': np.float64(0.57040798760544), 'Parch': np.float64(0.5579560452171918), 'Fare': np.float64(0.7432145521317496), 'Name_Abbott, Mr. Rossmore Edward': np.float64(0.5), 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': np.float64(0.5), 'Name_Abelson, Mr. Samuel': np.float64(0.5), 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': np.float64(0.5), 'Name_Adahl, Mr. Mauritz Nils Martin': np.float64(0.4968152866242038), 'Name_Adams, Mr. John': np.float64(0.5), 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': np.float64(0.5), 'Name_Aks, Mrs. Sam (Leah Rosen)': np.float64(0.5), 'Name_Albimona, Mr. Nassef Cassem': np.float64(0.5), 'Name_Alexander, Mr. William': np.float64(0.5), 'Name_Alhomaki, Mr. Ilmari Rudolf': np.float64(0.4968152866242038), 'Name_Ali, Mr. Ahmed': np.float64(0.4968152866242038), 'Name_Ali, Mr. William': np.float64(0.5), 'Name_Allen, Miss. Elisabeth Walton': np.float64(0.5), 'Name_Allen, Mr. William Henry': np.float64(0.5), 'Name_Allison, Master. Hudson Trevor': np.float64(0.5045045045045045), 'Name_Allison, Miss. Helen Loraine': np.float64(0.5), 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': np.float64(0.5), 'Name_Allum, Mr. Owen George': np.float64(0.5), 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': np.float64(0.5045045045045045), 'Name_Anderson, Mr. Harry': np.float64(0.5), 'Name_Andersson, Master. Sigvard Harald Elias': np.float64(0.5), 'Name_Andersson, Miss. Ebba Iris Alfrida': np.float64(0.4968152866242038), 'Name_Andersson, Miss. Ellis Anna Maria': np.float64(0.5), 'Name_Andersson, Miss. Erna Alexandra': np.float64(0.5), 'Name_Andersson, Miss. Ingeborg Constanzia': np.float64(0.4968152866242038), 'Name_Andersson, Miss. Sigrid Elisabeth': np.float64(0.4968152866242038), 'Name_Andersson, Mr. Anders Johan': np.float64(0.5), 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': np.float64(0.5), 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': np.float64(0.5), 'Name_Andreasson, Mr. Paul Edvin': np.float64(0.5), 'Name_Andrew, Mr. Edgardo Samuel': np.float64(0.5), 'Name_Andrews, Miss. Kornelia Theodosia': np.float64(0.5045045045045045), 'Name_Andrews, Mr. Thomas Jr': np.float64(0.5), 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': np.float64(0.5045045045045045), 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': np.float64(0.5), 'Name_Arnold-Franchi, Mr. Josef': np.float64(0.5), 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': np.float64(0.4968152866242038), 'Name_Artagaveytia, Mr. Ramon': np.float64(0.4968152866242038), 'Name_Asim, Mr. Adola': np.float64(0.4968152866242038), 'Name_Asplund, Master. Clarence Gustaf Hugo': np.float64(0.5), 'Name_Asplund, Master. Edvin Rojj Felix': np.float64(0.5), 'Name_Asplund, Miss. Lillian Gertrud': np.float64(0.5), 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': np.float64(0.5045045045045045), 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': np.float64(0.5), 'Name_Attalah, Miss. Malake': np.float64(0.5), 'Name_Attalah, Mr. Sleiman': np.float64(0.4968152866242038), 'Name_Aubart, Mme. Leontine Pauline': np.float64(0.5), 'Name_Augustsson, Mr. Albert': np.float64(0.4968152866242038), 'Name_Ayoub, Miss. Banoura': np.float64(0.5), 'Name_Backstrom, Mr. Karl Alfred': np.float64(0.5), 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)': np.float64(0.5), 'Name_Baclini, Miss. Eugenie': np.float64(0.5), 'Name_Baclini, Miss. Helene Barbara': np.float64(0.5), 'Name_Baclini, Miss. Marie Catherine': np.float64(0.5045045045045045), 'Name_Baclini, Mrs. Solomon (Latifa Qurban)': np.float64(0.5), 'Name_Badt, Mr. Mohamed': np.float64(0.5), 'Name_Bailey, Mr. Percy Andrew': np.float64(0.5), 'Name_Balkic, Mr. Cerin': np.float64(0.5), 'Name_Ball, Mrs. (Ada E Hall)': np.float64(0.5045045045045045), 'Name_Banfield, Mr. Frederick James': np.float64(0.5), 'Name_Barah, Mr. Hanna Assi': np.float6 ...
# Univariate MSE (Regression): {'PassengerId': 234665.89218395523, 'Pclass': 957.9519600746269, 'SibSp': 1060.2665869402986, 'Parch': 1060.7249451492537, 'Fare': 2211.525887399776, 'Name_Abbott, Mr. Rossmore Edward': 1078.8070347014925, 'Name_Abbott, Mrs. Stanton (Rosa Hunt)': 1078.8070347014925, 'Name_Abelson, Mr. Samuel': 1078.8070347014925, 'Name_Abelson, Mrs. Samuel (Hannah Wizosky)': 1078.8070347014925, 'Name_Adahl, Mr. Mauritz Nils Martin': 1078.5868854477612, 'Name_Adams, Mr. John': 1078.8070347014925, 'Name_Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': 1078.8070347014925, 'Name_Aks, Mrs. Sam (Leah Rosen)': 1078.8070347014925, 'Name_Albimona, Mr. Nassef Cassem': 1078.8070347014925, 'Name_Alexander, Mr. William': 1078.8070347014925, 'Name_Alhomaki, Mr. Ilmari Rudolf': 1078.6615123134327, 'Name_Ali, Mr. Ahmed': 1078.6316615671642, 'Name_Ali, Mr. William': 1078.8070347014925, 'Name_Allen, Miss. Elisabeth Walton': 1078.8070347014925, 'Name_Allen, Mr. William Henry': 1078.8070347014925, 'Name_Allison, Master. Hudson Trevor': 1078.8039003731344, 'Name_Allison, Miss. Helen Loraine': 1078.8070347014925, 'Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': 1078.8070347014925, 'Name_Allum, Mr. Owen George': 1078.8070347014925, 'Name_Andersen-Jensen, Miss. Carla Christine Nielsine': 1078.668975, 'Name_Anderson, Mr. Harry': 1078.8070347014925, 'Name_Andersson, Master. Sigvard Harald Elias': 1078.8070347014925, 'Name_Andersson, Miss. Ebba Iris Alfrida': 1078.765989925373, 'Name_Andersson, Miss. Ellis Anna Maria': 1078.8070347014925, 'Name_Andersson, Miss. Erna Alexandra': 1078.8070347014925, 'Name_Andersson, Miss. Ingeborg Constanzia': 1078.7436018656715, 'Name_Andersson, Miss. Sigrid Elisabeth': 1078.7286764925373, 'Name_Andersson, Mr. Anders Johan': 1078.8070347014925, 'Name_Andersson, Mr. August Edvard ("Wennerstrom")': 1078.8070347014925, 'Name_Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)': 1078.8070347014925, 'Name_Andreasson, Mr. Paul Edvin': 1078.8070347014925, 'Name_Andrew, Mr. Edgardo Samuel': 1078.8070347014925, 'Name_Andrews, Miss. Kornelia Theodosia': 1078.3406167910448, 'Name_Andrews, Mr. Thomas Jr': 1078.8070347014925, 'Name_Angle, Mrs. William A (Florence "Mary" Agnes Hughes)': 1078.5421093283583, 'Name_Appleton, Mrs. Edward Dale (Charlotte Lamson)': 1078.8070347014925, 'Name_Arnold-Franchi, Mr. Josef': 1078.8070347014925, 'Name_Arnold-Franchi, Mrs. Josef (Josefine Franchi)': 1078.6764376865672, 'Name_Artagaveytia, Mr. Ramon': 1078.2809152985074, 'Name_Asim, Mr. Adola': 1078.5495720149254, 'Name_Asplund, Master. Clarence Gustaf Hugo': 1078.8070347014925, 'Name_Asplund, Master. Edvin Rojj Felix': 1078.8070347014925, 'Name_Asplund, Miss. Lillian Gertrud': 1078.8070347014925, 'Name_Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)': 1078.5271839552238, 'Name_Astor, Mrs. John Jacob (Madeleine Talmadge Force)': 1078.8070347014925, 'Name_Attalah, Miss. Malake': 1078.8070347014925, 'Name_Attalah, Mr. Sleiman': 1078.5868854477612, 'Name_Aubart, Mme. Leontine Pauline': 1078.8070347014925, 'Name_Augustsson, Mr. Albert': 1078.6391242537313, 'Name_Ayoub, Miss. Banoura': 1078.8070347014925, 'Name_Backstrom, Mr. Karl Alfred': 1078.8070347014925, 'Name_Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)': 1078.8070347014925, 'Name_Baclini, Miss. Eugenie': 1078.8070347014925, 'Name_Baclini, Miss. Helene Barbara': 1078.8070347014925, 'Name_Baclini, Miss. Marie Catherine': 1078.7734526119402, 'Name_Baclini, Mrs. Solomon (Latifa Qurban)': 1078.8070347014925, 'Name_Badt, Mr. Mohamed': 1078.8070347014925, 'Name_Bailey, Mr. Percy Andrew': 1078.8070347014925, 'Name_Balkic, Mr. Cerin': 1078.8070347014925, 'Name_Ball, Mrs. (Ada E Hall)': 1078.5421093283583, 'Name_Banfield, Mr. Frederick James': 1078.8070347014925, 'Name_Barah, Mr. Hanna Assi': 1078.6615123134327, 'Name_Barbara, Miss. Saiide': 1078.8070347014925, 'Name_Barbara, Mrs. (Catherine David)': 1078.4749451492537, 'Name_Barber, Miss. Ellen "Nellie"': 1078.6 ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.feature_selection import RFE
from itertools import combinations
import numpy as np

# Load dataset
df = pd.read_csv("titanic_train.csv")

# Define features (X) and target (y)
X = pd.get_dummies(df.drop(columns=["Survived"]), drop_first=True).fillna(0)
y = df["Survived"]

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LogisticRegression(max_iter=500)

# -----------------------------------
# 1. Forward Selection
# -----------------------------------
sfs_forward = SFS(model,
                  k_features="best",
                  forward=True,
                  floating=False,
                  scoring="accuracy",
                  cv=5)
sfs_forward = sfs_forward.fit(X_train, y_train)
print("Forward Selection Features:", sfs_forward.k_feature_names_)

# -----------------------------------
# 2. Backward Selection
# -----------------------------------
sfs_backward = SFS(model,
                   k_features="best",
                   forward=False,
                   floating=False,
                   scoring="accuracy",
                   cv=5)
sfs_backward = sfs_backward.fit(X_train, y_train)
print("Backward Selection Features:", sfs_backward.k_feature_names_)

# -----------------------------------
# 3. Exhaustive Search (all possible combinations)
# -----------------------------------
sfs_exhaustive = SFS(model,
                     k_features=3,    # example: best 3 features
                     forward=True,
                     floating=False,
                     scoring="accuracy",
                     cv=5)
sfs_exhaustive = sfs_exhaustive.fit(X_train, y_train)
print("Exhaustive Search Best Features:", sfs_exhaustive.k_feature_names_)

# -----------------------------------
# 4. Recursive Feature Elimination (RFE)
# -----------------------------------
rfe = RFE(estimator=model, n_features_to_select=5)   # keep 5 best features
rfe = rfe.fit(X_train, y_train)

# i) Ranking Features
print("RFE Feature Ranking:", dict(zip(X.columns, rfe.ranking_)))

# ii) Selected Features
print("Selected Features by RFE:", X.columns[rfe.support_].tolist())

# iii) Stopping Criterion is defined by `n_features_to_select`
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_csv("titanic_train.csv")

# Features and target
X = pd.get_dummies(df.drop(columns=["Survived"]), drop_first=True).fillna(0)
y = df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# ------------------------------
# 1. L1 Regularization (LASSO)
# ------------------------------
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)
lasso_coef = pd.Series(lasso.coef_, index=X.columns)
print("LASSO Selected Features:", list(lasso_coef[lasso_coef != 0].index))

# ------------------------------
# 2. L2 Regularization (Ridge)
# ------------------------------
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
ridge_coef = pd.Series(ridge.coef_, index=X.columns)
print("Ridge Feature Coefficients:\n", ridge_coef)

# ------------------------------
# 3. Elastic Net (L1 + L2)
# ------------------------------
elastic = ElasticNet(alpha=0.01, l1_ratio=0.5)
elastic.fit(X_train, y_train)
elastic_coef = pd.Series(elastic.coef_, index=X.columns)
print("Elastic Net Selected Features:", list(elastic_coef[elastic_coef != 0].index))

# ------------------------------
# 4. Decision Tree
# ------------------------------
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
dt_importance = pd.Series(dt.feature_importances_, index=X.columns)
print("Decision Tree Important Features:", dt_importance.sort_values(ascending=False).head(10))

# ------------------------------
# 5. Random Forest
# ------------------------------
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_importance = pd.Series(rf.feature_importances_, index=X.columns)
print("Random Forest Important Features:", rf_importance.sort_values(ascending=False).head(10))

# ------------------------------
# 6. Support Vector Machine (SVM with L1 penalty)
# ------------------------------
svm = LogisticRegression(penalty="l1", solver="liblinear", max_iter=500)
svm.fit(X_train, y_train)
svm_coef = pd.Series(svm.coef_[0], index=X.columns)
print("SVM (L1) Selected Features:", list(svm_coef[svm_coef != 0].index))
# Out:
# LASSO Selected Features: ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Fare', 'Sex_male', 'Embarked_S']
# Ridge Feature Coefficients:
#  PassengerId    0.000024
# Pclass        -0.134211
# Age           -0.001835
# SibSp         -0.012512
# Parch         -0.008556
#                  ...
# Cabin_F4       0.170569
# Cabin_G6      -0.082044
# Cabin_T       -0.080701
# Embarked_Q    -0.042402
# Embarked_S    -0.088150
# Length: 1725, dtype: float64
# Elastic Net Selected Features: ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_male', 'Embarked_S']
# Decision Tree Important Features: Sex_male             0.283660
# Fare                 0.100795
# Pclass               0.087120
# PassengerId          0.034328
# Age                  0.021430
# SibSp                0.013234
# Ticket_113781        0.013014
# Ticket_C.A. 37671    0.010100
# Cabin_E24            0.009988
# Cabin_F2             0.009877
# dtype: float64
# Random Forest Important Features: Sex_male       0.132107
# Fare           0.066437
# PassengerId    0.049036
# Pclass         0.045627
# Age            0.044009
# Parch          0.023655
# SibSp          0.021374
# Embarked_S     0.014306
# Embarked_Q     0.004436
# Ticket_1601    0.003938
# dtype: float64
# SVM (L1) Selected Features: ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_male', 'Ticket_113781', 'Ticket_1601', 'Ticket_230080', 'Ticket_230136', 'Ticket_2653', 'Ticket_2665', 'Ticket_2908', 'Ticket_29106', 'Ticket_345773', 'Ticket_347054', 'Ticket_347077', 'Ticket_347088', 'Ticket_347742', 'Ticket_349909', 'Ticket_367226', 'Ticket_392096', 'Ticket_C.A. 37671', 'Ticket_PC 17572', 'Cabin_C22 C26', 'Cabin_E121', 'Cabin_E24', 'Cabin_F2', 'Cabin_F4', 'Embarked_Q', 'Embarked_S']
